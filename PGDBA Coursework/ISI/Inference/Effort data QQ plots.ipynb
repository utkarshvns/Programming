# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy import stats

import statsmodels.api as sm
import pylab as py

# %%
df = pd.read_excel("D:\PGDBA Backup\ISI\AB-Inference\Assignments\Datasets\Effort and Arrival.xlsx")
# Out:
# C:\Users\utkar\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:308: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#    Job Level of the employee  # of years of experience     ITILProcessType  \
# 0                          3                      0.72  Release Management
# 1                          3                      0.72  Release Management
# 2                          3                      2.75     Service Request
# 3                          3                      0.72  Release Management
# 4                          3                      0.72  Release Management
#
#   Complexity  Effort Service Domain type
# 0     Medium      55          App suport
# 1     Medium      55          App suport
# 2     Medium      72    Database Support
# 3     Medium      55          App suport
# 4     Medium      55          App suport

# %%
df.describe()
# Out:
#        Job Level of the employee  # of years of experience       Effort
# count                6460.000000               6447.000000  6460.000000
# mean                    3.107121                  2.542984    81.263777
# std                     0.518712                  1.738865    84.607490
# min                     2.000000                  0.720000     1.000000
# 25%                     3.000000                  1.230000    30.000000
# 50%                     3.000000                  2.060000    52.000000
# 75%                     3.000000                  3.380000   103.000000
# max                     5.000000                 11.760000   646.000000

# %%
effort = np.array(df["Effort"])
effort
# Out:
# array([55, 55, 72, ..., 94, 76, 89], dtype=int64)

# %%
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
norm_effort
# Out:
# array([-0.31044308, -0.31044308, -0.10949969, ...,  0.15054469,
#        -0.0622189 ,  0.0914437 ])

# %%
res = stats.probplot(effort, plot=plt)

# %%
res = stats.probplot(norm_effort, plot=plt)

# %%
print(df["ITILProcessType"].unique())
print(df["Complexity"].unique())
print(df["Service Domain type"].unique())
# Out:
# ['Release Management' 'Service Request' 'Incident Management']
# ['Medium' 'Simple' 'Complex']
# ['App suport' 'Database Support']

# %%
df[(df["ITILProcessType"]=="Release Management")
   &(df["Complexity"]=="Medium")
   &(df["Service Domain type"]=="App suport")]
# Out:
#       Job Level of the employee  # of years of experience     ITILProcessType  \
# 0                             3                      0.72  Release Management
# 1                             3                      0.72  Release Management
# 3                             3                      0.72  Release Management
# 4                             3                      0.72  Release Management
# 5                             3                      0.72  Release Management
# ...                         ...                       ...                 ...
# 6377                          3                      3.07  Release Management
# 6378                          5                      7.72  Release Management
# 6428                          3                      2.06  Release Management
# 6458                          3                      1.90  Release Management
# 6459                          3                      1.90  Release Management
#
# ...

# %%
plt.figure(figsize=(30,30))

plt.subplot(6,3,1)
effort = np.array(df[(df["ITILProcessType"]=="Release Management")&(df["Complexity"]=="Medium")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Release Management||Medium||App suport")

plt.subplot(6,3,2)
effort = np.array(df[(df["ITILProcessType"]=="Release Management")&(df["Complexity"]=="Medium")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Release Management||Medium||Database Support")


plt.subplot(6,3,3)
effort = np.array(df[(df["ITILProcessType"]=="Release Management")&(df["Complexity"]=="Simple")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Release Management||Simple||App suport")

plt.subplot(6,3,4)
effort = np.array(df[(df["ITILProcessType"]=="Release Management")&(df["Complexity"]=="Simple")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Release Management||Simple||Database Support")

plt.subplot(6,3,5)
effort = np.array(df[(df["ITILProcessType"]=="Release Management")&(df["Complexity"]=="Complex")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Release Management||Complex||App suport")

plt.subplot(6,3,6)
effort = np.array(df[(df["ITILProcessType"]=="Release Management")&(df["Complexity"]=="Complex")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Release Management||Complex||Database Support")

plt.subplot(6,3,7)
effort = np.array(df[(df["ITILProcessType"]=="Service Request")&(df["Complexity"]=="Medium")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Service Request||Medium||App suport")

plt.subplot(6,3,8)
effort = np.array(df[(df["ITILProcessType"]=="Service Request")&(df["Complexity"]=="Medium")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Service Request||Medium||Database Support")

plt.subplot(6,3,9)
effort = np.array(df[(df["ITILProcessType"]=="Service Request")&(df["Complexity"]=="Simple")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Service Request||Simple||App suport")

plt.subplot(6,3,10)
effort = np.array(df[(df["ITILProcessType"]=="Service Request")&(df["Complexity"]=="Simple")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Service Request||Simple||Database Support")

plt.subplot(6,3,11)
effort = np.array(df[(df["ITILProcessType"]=="Service Request")&(df["Complexity"]=="Complex")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Service Request||Complex||App suport")

plt.subplot(6,3,12)
effort = np.array(df[(df["ITILProcessType"]=="Service Request")&(df["Complexity"]=="Complex")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Service Request||Complex||Database Support")

plt.subplot(6,3,13)
effort = np.array(df[(df["ITILProcessType"]=="Incident Management")&(df["Complexity"]=="Medium")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Incident Management||Medium||App suport")

plt.subplot(6,3,14)
effort = np.array(df[(df["ITILProcessType"]=="Incident Management")&(df["Complexity"]=="Medium")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Incident Management||Medium||Database Support")

plt.subplot(6,3,15)
effort = np.array(df[(df["ITILProcessType"]=="Incident Management")&(df["Complexity"]=="Simple")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Incident Management||Simple||App suport")

plt.subplot(6,3,16)
effort = np.array(df[(df["ITILProcessType"]=="Incident Management")&(df["Complexity"]=="Simple")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Incident Management||Simple||Database Support")

plt.subplot(6,3,17)
effort = np.array(df[(df["ITILProcessType"]=="Incident Management")&(df["Complexity"]=="Complex")&(df["Service Domain type"]=="App suport")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Incident Management||Complex||App suport")

plt.subplot(6,3,18)
effort = np.array(df[(df["ITILProcessType"]=="Incident Management")&(df["Complexity"]=="Complex")&(df["Service Domain type"]=="Database Support")]["Effort"])
norm_effort = ((effort - np.mean(effort)) / np.std(effort))
res = stats.probplot(norm_effort, plot=plt)
plt.gca().set_title("Incident Management||Complex||Database Support")
# Out:
# Text(0.5, 1.0, 'Incident Management||Complex||Database Support')
