# %% [markdown]
# # Boston Data

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel("D:\PGDBA Backup\ISI\AB-Inference\Assignments\Datasets\Boston_Housing Data.xlsx")

# %% [markdown]
# This dataset contains information collected by the US Census Service concerning housing in the area of Boston Massachusetts. It was obtained from the StatLib archive (http://lib.stat.cmu.edu/datasets/boston). The dataset has 506 cases.
#
# The data was originally published by Harrison, D. and Rubinfeld, D.L. `Hedonic prices and the demand for clean air', J. Environ. Economics & Management, vol.5, 81-102, 1978.
#
# There are 14 attributes in each case of the dataset. They are:
#
# CRIM   :  per capita crime rate by town
#
# ZN     :    proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS  :  proportion of non-retail business acres per town.
#
# CHAS   :  Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# NOX    :   nitric oxides concentration (parts per 10 million)
#
# RM     :   average number of rooms per dwelling
#
# AGE    :   proportion of owner-occupied units built prior to 1940
#
# DIS    :   weighted distances to five Boston employment centres
#
# RAD    :  index of accessibility to radial highways
#
# TAX    :  full-value property-tax rate per $10,000
#
# PTRATIO: pupil-teacher ratio by town
#
# B      :    1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
# LSTAT  : % lower status of the population
#
# MEDV   : Median value of owner-occupied homes in $1000

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
g = sns.PairGrid(df)
g.map(sns.scatterplot)
plt.show()

# %%
# g = sns.FacetGrid(df)
# g.map(sns.scatterplot, "CRIM", "MEDV", alpha=.7)
# g.map(sns.scatterplot, "ZN", "MEDV", alpha=.7)
# g.add_legend()

# %%
plt.scatter(data = df, x="CRIM", y="MEDV")
plt.xlabel("CRIM")
plt.ylabel("MEDV")
plt.title('CRIM vs MEDV')

plt.show()

# %%
plt.figure(figsize=(20, 20))

plt.subplot(4,4,1)
plt.scatter(data = df, x="CRIM", y="MEDV")
plt.xlabel("CRIM")
plt.ylabel("MEDV")

plt.subplot(4,4,2)
plt.scatter(data = df, x="ZN", y="MEDV")
plt.xlabel("ZN")
plt.ylabel("MEDV")

plt.subplot(4,4,3)
plt.scatter(data = df, x="INDUS", y="MEDV")
plt.xlabel("INDUS")
plt.ylabel("MEDV")

plt.subplot(4,4,4)
plt.scatter(data = df, x="CHAS", y="MEDV")
plt.xlabel("CHAS")
plt.ylabel("MEDV")

plt.subplot(4,4,5)
plt.scatter(data = df, x="NOX", y="MEDV")
plt.xlabel("NOX")
plt.ylabel("MEDV")

plt.subplot(4,4,6)
plt.scatter(data = df, x="RM", y="MEDV")
plt.xlabel("RM")
plt.ylabel("MEDV")

plt.subplot(4,4,7)
plt.scatter(data = df, x="AGE", y="MEDV")
plt.xlabel("AGE")
plt.ylabel("MEDV")

plt.subplot(4,4,8)
plt.scatter(data = df, x="DIS", y="MEDV")
plt.xlabel("DIS")
plt.ylabel("MEDV")

plt.subplot(4,4,9)
plt.scatter(data = df, x="RAD", y="MEDV")
plt.xlabel("RAD")
plt.ylabel("MEDV")

plt.subplot(4,4,10)
plt.scatter(data = df, x="TAX", y="MEDV")
plt.xlabel("TAX")
plt.ylabel("MEDV")

plt.subplot(4,4,11)
plt.scatter(data = df, x="PTRATIO", y="MEDV")
plt.xlabel("PTRATIO")
plt.ylabel("MEDV")

plt.subplot(4,4,12)
plt.scatter(data = df, x="B", y="MEDV")
plt.xlabel("B")
plt.ylabel("MEDV")

plt.subplot(4,4,13)
plt.scatter(data = df, x="LSTAT", y="MEDV")
plt.xlabel("LSTAT")
plt.ylabel("MEDV")

plt.show()

# %% [markdown]
# # Naive regression

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# x = "CRIM"
# y = "MEDV"

# span = 40
# n = int(len(df)/span)+1

# df_sort = df.sort_values(by=x).reset_index(drop=True)

# df_split  = np.array_split(df_sort, n)

# X_avg = []
# Y_avg = []

# for i in range(0, n):
#     X_avg.append(np.mean(df_split[i][x]))
#     Y_avg.append(np.mean(df_split[i][y]))

# %%
def naiveRegression(x,y,sp):
    span = sp
    if (len(df)%span == 0):
        n = int(len(df)/span)
    else:
        n = int(len(df)/span)+1
    
    df_sort = df.sort_values(by=x).reset_index(drop=True)

    df_split  = np.array_split(df_sort, n)

    X_avg = []
    Y_avg = []

    for i in range(0, n):
        X_avg.append(np.mean(df_split[i][x]))
        Y_avg.append(np.mean(df_split[i][y]))
    return X_avg,Y_avg

# %%
X_naive,Y_naive = naiveRegression("CRIM","MEDV",40)

# %%
# X_naive,Y_naive

# %%
plt.figure(figsize=(5,5))
plt.plot(X_naive,Y_naive)
plt.xlabel("CRIM")
plt.ylabel("MEDV")
plt.show()

# %% [markdown]
# # Local Averaging

# %% [markdown]
# https://towardsdatascience.com/moving-averages-in-python-16170e20f6c

# %%
# x = "CRIM"
# y = "MEDV"
# n=10

# df_sort = df.sort_values(by=x).reset_index(drop=True)

# df_sort["SMA-X"] = df_sort[x].rolling(n,min_periods=1).mean()
# df_sort["SMA-Y"] = df_sort[y].rolling(n,min_periods=1).mean()

# %%
def localAverageRegression(x,y,sp):
    df_sort = df.sort_values(by=x).reset_index(drop=True)

    df_sort["SMA-X"] = df_sort[x].rolling(n,min_periods=1).mean()
    df_sort["SMA-Y"] = df_sort[y].rolling(n,min_periods=1).mean()
    return df_sort["SMA-X"],df_sort["SMA-Y"]

# %%
df_sort.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.00906  90.0   2.97     0  0.400  7.088  20.8  7.3073    1  285     15.3
# 2  0.01096  55.0   2.25     0  0.389  6.453  31.9  7.3073    1  300     15.3
# 3  0.01301  35.0   1.52     0  0.442  7.241  49.3  7.0379    1  284     15.5
# 4  0.01311  90.0   1.22     0  0.403  7.249  21.9  8.6966    5  226     17.9
#
#         B  LSTAT  MEDV     SMA-X      SMA-Y
# 0  396.90   4.98  24.0  0.006320  24.000000
# 1  394.72   7.85  32.2  0.007690  28.100000
# 2  394.72   8.23  22.0  0.008780  26.066667
# 3  394.74   5.49  32.7  0.009838  27.725000
# 4  395.93   4.81  35.4  0.010492  29.260000

# %%
X_locAvg,Y_locAvg=localAverageRegression("CRIM","MEDV",100)

# %%
# X_loc,Y_loc

# %%
plt.figure(figsize=(5,5))
plt.plot(X_locAvg,Y_locAvg)
plt.xlabel("CRIM")
plt.ylabel("MEDV")
plt.show()

# %% [markdown]
# # Lowess

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.regplot.html
#
# https://www.statsmodels.org/stable/generated/statsmodels.nonparametric.smoothers_lowess.lowess.html

# %%
# Statsmodel implementation

a = sm.nonparametric.lowess(df["MEDV"],df["CRIM"],frac=0.1)
b = sm.nonparametric.lowess(df["MEDV"],df["CRIM"],frac=0.3)
c = sm.nonparametric.lowess(df["MEDV"],df["CRIM"],frac=0.6)

plt.figure(figsize=(20, 5))

plt.subplot(1,3,1)
plt.plot(a[:,0],a[:,1])
plt.xlabel("CRIM")
plt.ylabel("MEDV")

plt.subplot(1,3,2)
plt.plot(b[:,0],b[:,1])
plt.xlabel("CRIM")
plt.ylabel("MEDV")

plt.subplot(1,3,3)
plt.plot(c[:,0],c[:,1])
plt.xlabel("CRIM")
plt.ylabel("MEDV")

plt.show()

# %%
a = sm.nonparametric.lowess(df["MEDV"],df["CRIM"])

plt.plot(a[:,0],a[:,1])
plt.xlabel("CRIM")
plt.ylabel("MEDV")
plt.show()

# %%
# Seaborn implementation

plt.figure(figsize=(20, 5))

plt.subplot(1,3,1)
sns.regplot(data=df, x="CRIM", y="MEDV",lowess=True,scatter=False)

plt.subplot(1,3,2)
sns.regplot(data=df, x="CRIM", y="MEDV",lowess=True)

# %% [markdown]
# # Kernel Regression

# %%
b = sm.nonparametric.KernelReg(endog=df["MEDV"],exog=df["CRIM"], var_type='c')

# %% [markdown]
# -----------------

# %% [markdown]
# # Significant relationships

# %% [markdown]
# CRIM
# INDUS
# NOX
# RM
# AGE
# DIS
# PTRATIO
# B
# LSTAT

# %%
sns.regplot(data=df, x="CRIM", y="MEDV",lowess=True,scatter=False)
plt.show()

# %%
sns.regplot(data=df, x="INDUS", y="MEDV",lowess=True,scatter=False)
plt.show()

# %%
sns.regplot(data=df, x="NOX", y="MEDV",lowess=True,scatter=False)
plt.show()

# %%
sns.regplot(data=df, x="RM", y="MEDV",lowess=True,scatter=False)
plt.show()

# %%
sns.regplot(data=df, x="AGE", y="MEDV",lowess=True,scatter=False)
plt.show()

# %%
sns.regplot(data=df, x="DIS", y="MEDV",lowess=True,scatter=False)
plt.show()

# %%
sns.regplot(data=df, x="PTRATIO", y="MEDV",lowess=True,scatter=False)
plt.show()

# %%
sns.regplot(data=df, x="B", y="MEDV",lowess=True,scatter=False)
plt.show()

# %%
sns.regplot(data=df, x="LSTAT", y="MEDV",lowess=True,scatter=False)
plt.show()

# %% [markdown]
# # References
#
#
# Other NPR
#
# https://pypi.org/project/PyQt-Fit/
#
# https://pythonhosted.org/PyQt-Fit/NonParam_tut.html#types-of-regressions
#
#
#
#
# Moving Averages
#
# https://towardsdatascience.com/moving-averages-in-python-16170e20f6c
#
#
# Lowess
#
# https://seaborn.pydata.org/generated/seaborn.regplot.html
#
# https://www.statsmodels.org/stable/generated/statsmodels.nonparametric.smoothers_lowess.lowess.html
#
#
# Kernel Reg
#
# https://www.statsmodels.org/devel/generated/statsmodels.nonparametric.kernel_regression.KernelReg.html
#
#
# Multiplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
