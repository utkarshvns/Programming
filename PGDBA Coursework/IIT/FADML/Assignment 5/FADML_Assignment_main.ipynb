# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
import argparse

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, kernel_size=5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 6, kernel_size =5)
        self.fc1 = nn.Linear(6*5*5, 120)
        self.fc2 = nn.Linear(120, 84 )
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x 

def convfc():
    model_arch = Net()
    return model_arch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import pandas as pd
import numpy as np
import torchvision
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import os
import argparse
import seaborn as sns
import matplotlib.pyplot as plt
import torchvision.models as models
# %pip install wandb -q
import wandb
# import Fadml_Assignment_model

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0  # best test accuracy

# %%
wandb.init(project="pytorch-CIFAR",reinit=True)
wandb.watch_called = False # Re-run the model without restarting the runtime, unnecessary after our next release
# Out:
# wandb: Currently logged in as: vatangl14 (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">soft-durian-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/vatangl14/pytorch-CIFAR" target="_blank">https://wandb.ai/vatangl14/pytorch-CIFAR</a><br/>
#                 Run page: <a href="https://wandb.ai/vatangl14/pytorch-CIFAR/runs/tr5tdg91" target="_blank">https://wandb.ai/vatangl14/pytorch-CIFAR/runs/tr5tdg91</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210528_123906-tr5tdg91</code><br/><br/>

# %%
device
# Out:
# 'cuda'

# %%
# Data
print('Data transformation')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
# Out:
# Data transformation

# %%
validation_split = .2
shuffle_dataset = True
random_seed= 42


trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)

# Creating data indices for training and validation splits:
dataset_size = len(trainset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)


trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=128,num_workers=2,sampler=train_sampler)

validationloader = torch.utils.data.DataLoader(
    trainset, batch_size=128, num_workers=2,sampler=valid_sampler)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainloader

# %%
# #Model
# print('Model creation')
# net =Net()
# net = net.to(device)
# Out:
# Model creation

# %%
# Training
def train(epoch,net,criterion,optimizer):
    print('\nEpoch: %d' % epoch)
    net.train()

    running_loss = 0.0
    val_running_loss = 0.0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        # Write your code here
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs).to(device)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
    running_loss_history.append(running_loss)
    #Write training losses to losstrain.txt for each epoch
    ## Creating a dictionary to store the epoch and the losses corresponding to that
    losstrain={'epoch': [epoch],'loss':[running_loss]}
    ## Making a dataframe from this dictionary
    loss_df = pd.DataFrame.from_dict(losstrain)
    ## Making a txt file from this dataframe
    loss_df.to_csv(r'train_loss.txt', header=None, index=None, sep=' ', mode='a')
    print('Finished Training')
    print('Training Loss: %d' % running_loss)
    wandb.log({"Training Loss": running_loss})

    with torch.no_grad(): # we do not need gradient for validation.
      for val_inputs, val_labels in validationloader:
        val_inputs = val_inputs.to(device)
        val_labels = val_labels.to(device)
        val_outputs = net(val_inputs)
        val_loss = criterion(val_outputs, val_labels)
        
        _, val_preds = torch.max(val_outputs, 1)
        val_running_loss += val_loss.item()
    val_running_loss_history.append(val_running_loss)
    wandb.log({"Validation Loss": val_running_loss})

# %%
def test(epoch,net,criterion):
  global best_acc
  net.eval()
  total = 0
  correct = 0
  test_loss = 0
  test_images = []
  print('\nEpoch: %d' % epoch)
  with torch.no_grad():
      for batch_idx, (inputs, targets) in enumerate(testloader):
          inputs, targets = inputs.to(device), targets.to(device)
          ## Giving input to the model
          outputs = net(inputs)
          loss = criterion(outputs, targets)
          ## Predicting on the input data
          _, predicted = torch.max(outputs.data, 1)
          ## Defining the total size of the target
          total += targets.size(0)
          ## Getting the total number of correctly classified labels
          test_loss += loss.item()
          correct += (predicted == targets).sum().item()
          ## Appending images to image list
          test_images.append(wandb.Image(inputs[0], caption="Pred: {} Truth: {}".format(predicted[0].item(), targets[0])))
          ## Getting the accuracy of the model
      model_accuracy = 100 * correct / total
      print('Testing Accuracy: %d ' % model_accuracy)
      print('\n')
      ## Checking whether the accuracy is better than the best accuracy
      if model_accuracy>best_acc:
      ## Saving the new value of best_accuracy
        best_acc = model_accuracy
        ## Saving the model
        # Save checkpoint for the model which yields best accuracy
        PATH = './cifar_net.pth'
        torch.save(net.state_dict(), PATH)
          # Write test set losses to losstest.txt for each epoch
      df={'epoch': [epoch],'loss':[test_loss]}
      data = pd.DataFrame.from_dict(df)
      data.to_csv(r'losstest.txt', header=None, index=None, sep=' ', mode='a')
      #Write test set accuracies to acctest.txt for each epoch
      testaccuracy={'epoch': [epoch],'test_accuracy':[model_accuracy]}
      ## Making a dataframe from this dictionary
      accuracy_df = pd.DataFrame.from_dict(testaccuracy)
      ## Making a txt file from this dataframe
      accuracy_df.to_csv(r'test_accuracy.txt', header=None, index=None, sep=' ', mode='a')
      wandb.log({"Testing_images": test_images,"Test Accuracy": 100. * correct / len(testloader.dataset),"Test Loss": test_loss})   
  # Write test set losses to losstest.txt for each epoch

# %%
def training_testing(net,criterion,optimizer):
  n_epochs_stop = 20
  epochs_no_improve = 0
  for epoch in range(0,500):
    print("Model Training")
    train(epoch,net,criterion,optimizer)
    if val_running_loss_history[epoch]>val_running_loss_history[epoch-1]:
      if(epochs_no_improve<n_epochs_stop):
        epochs_no_improve+=1
      else:
        break
    else:
      epochs_no_improve=0
    print("\n Model Testing")
    test(epoch,net,criterion)

# %%
run=wandb.init(project="pytorch-CIFAR-Vatan_500",reinit=True)
wandb.watch_called = False # Re-run the model w
net1 = convfc()
wandb.watch(net1,log="all")
net1 = net1.to(device)
running_loss_history = []
val_running_loss_history = []
### Defining a Loss function and optimizer for configuration 1
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net1.parameters(), lr=0.001, momentum=0.9)
training_testing(net1,criterion,optimizer)
# Out:
# Finishing last run (ID:3mm6yco9) before initializing another...
# <br/>Waiting for W&B process to finish, PID 15874<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210528_134011-3mm6yco9/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210528_134011-3mm6yco9/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training Loss</td><td>720.63542</td></tr><tr><td>_runtime</td><td>16</td></tr><tr><td>_timestamp</td><td>1622209230</td></tr><tr><td>_step</td><td>1</td></tr><tr><td>Validation Loss</td><td>181.61523</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training Loss</td><td>▁</td></tr><tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>Validation Loss</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">easy-thunder-2</strong>: <a href="https://wandb.ai/vatangl14/pytorch-CIFAR-Vatan_500/runs/3mm6yco9" target="_blank">https://wandb.ai/vatangl14/pytorch-CIFAR-Vatan_500/runs/3mm6yco9</a><br/>
# ...Successfully finished last run (ID:3mm6yco9). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">genial-mountain-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/vatangl14/pytorch-CIFAR-Vatan_500" target="_blank">https://wandb.ai/vatangl14/pytorch-CIFAR-Vatan_500</a><br/>
#                 Run page: <a href="https://wandb.ai/vatangl14/pytorch-CIFAR-Vatan_500/runs/1l8sanhb" target="_blank">https://wandb.ai/vatangl14/pytorch-CIFAR-Vatan_500/runs/1l8sanhb</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210528_134147-1l8sanhb</code><br/><br/>
# Model Training
#
# Epoch: 0
# Finished Training
# Training Loss: 719
#
#  Model Testing
#
# Epoch: 0
# Testing Accuracy: 13
#
#
# Model Training
#
# Epoch: 1
# Finished Training
# Training Loss: 704
#
#  Model Testing
#
# Epoch: 1
# Testing Accuracy: 22
#
#
# Model Training
#
# Epoch: 2
# Finished Training
# Training Loss: 676
#
#  Model Testing
#
# Epoch: 2
# Testing Accuracy: 27
#
#
# Model Training
#
# Epoch: 3
# Finished Training
# Training Loss: 651
#
#  Model Testing
#
# Epoch: 3
# Testing Accuracy: 29
#
#
# Model Training
#
# Epoch: 4
# Finished Training
# Training Loss: 611
#
#  Model Testing
#
# Epoch: 4
# Testing Accuracy: 33
#
#
# Model Training
#
# Epoch: 5
# Finished Training
# Training Loss: 582
#
#  Model Testing
#
# Epoch: 5
# Testing Accuracy: 35
#
#
# Model Training
#
# Epoch: 6
# Finished Training
# Training Loss: 564
#
#  Model Testing
#
# Epoch: 6
# Testing Accuracy: 36
#
#
# Model Training
#
# Epoch: 7
# Finished Training
# Training Loss: 547
#
#  Model Testing
#
# Epoch: 7
# Testing Accuracy: 39
#
#
# Model Training
#
# Epoch: 8
# Finished Training
# Training Loss: 532
#
#  Model Testing
#
# Epoch: 8
# Testing Accuracy: 39
#
#
# Model Training
#
# Epoch: 9
# Finished Training
# Training Loss: 522
#
#  Model Testing
#
# Epoch: 9
# Testing Accuracy: 42
#
#
# Model Training
#
# Epoch: 10
# Finished Training
# Training Loss: 516
#
#  Model Testing
#
# Epoch: 10
# Testing Accuracy: 41
#
#
# Model Training
#
# Epoch: 11
# Finished Training
# Training Loss: 508
#
#  Model Testing
#
# Epoch: 11
# Testing Accuracy: 43
#
#
# Model Training
#
# Epoch: 12
# Finished Training
# Training Loss: 501
#
#  Model Testing
#
# Epoch: 12
# Testing Accuracy: 44
#
#
# Model Training
#
# Epoch: 13
# Finished Training
# Training Loss: 495
#
#  Model Testing
#
# Epoch: 13
# Testing Accuracy: 45
#
#
# Model Training
#
# Epoch: 14
# Finished Training
# Training Loss: 488
#
#  Model Testing
#
# Epoch: 14
# Testing Accuracy: 46
#
#
# Model Training
#
# Epoch: 15
# Finished Training
# Training Loss: 480
#
#  Model Testing
#
# Epoch: 15
# Testing Accuracy: 47
#
#
# Model Training
#
# Epoch: 16
# Finished Training
# Training Loss: 474
#
#  Model Testing
#
# Epoch: 16
# Testing Accuracy: 48
#
#
# Model Training
#
# Epoch: 17
# Finished Training
# Training Loss: 471
#
#  Model Testing
#
# Epoch: 17
# Testing Accuracy: 49
#
#
# Model Training
#
# Epoch: 18
# Finished Training
# Training Loss: 466
#
#  Model Testing
#
# Epoch: 18
# Testing Accuracy: 49
#
#
# Model Training
#
# Epoch: 19
# Finished Training
# Training Loss: 460
#
#  Model Testing
#
# Epoch: 19
# Testing Accuracy: 49
#
#
# Model Training
#
# Epoch: 20
# Finished Training
# Training Loss: 458
#
#  Model Testing
#
# Epoch: 20
# Testing Accuracy: 50
#
#
# Model Training
#
# Epoch: 21
# Finished Training
# Training Loss: 454
#
#  Model Testing
#
# Epoch: 21
# Testing Accuracy: 49
#
#
# Model Training
#
# Epoch: 22
# Finished Training
# Training Loss: 451
#
#  Model Testing
#
# Epoch: 22
# Testing Accuracy: 50
#
#
# Model Training
#
# Epoch: 23
# Finished Training
# Training Loss: 446
#
#  Model Testing
#
# Epoch: 23
# Testing Accuracy: 51
#
#
# Model Training
#
# Epoch: 24
# Finished Training
# Training Loss: 445
#
#  Model Testing
#
# Epoch: 24
# Testing Accuracy: 50
#
#
# Model Training
#
# Epoch: 25
# Finished Training
# Training Loss: 443
#
#  Model Testing
#
# Epoch: 25
# Testing Accuracy: 51
#
#
# Model Training
#
# Epoch: 26
# Finished Training
# Training Loss: 440
#
#  Model Testing
#
# Epoch: 26
# Testing Accuracy: 53
#
#
# Model Training
#
# Epoch: 27
# Finished Training
# Training Loss: 436
#
#  Model Testing
#
# Epoch: 27
# Testing Accuracy: 52
#
#
# Model Training
#
# Epoch: 28
# Finished Training
# Training Loss: 434
#
#  Model Testing
#
# Epoch: 28
# Testing Accuracy: 52
#
#
# Model Training
#
# Epoch: 29
# Finished Training
# Training Loss: 431
#
#  Model Testing
#
# Epoch: 29
# Testing Accuracy: 52
#
#
# Model Training
#
# Epoch: 30
# Finished Training
# Training Loss: 428
#
#  Model Testing
#
# Epoch: 30
# Testing Accuracy: 51
#
#
# Model Training
#
# Epoch: 31
# Finished Training
# Training Loss: 427
#
#  Model Testing
#
# Epoch: 31
# Testing Accuracy: 52
#
#
# Model Training
#
# Epoch: 32
# Finished Training
# Training Loss: 425
#
#  Model Testing
#
# Epoch: 32
# Testing Accuracy: 53
#
#
# Model Training
#
# Epoch: 33
# Finished Training
# Training Loss: 423
#
#  Model Testing
#
# Epoch: 33
# Testing Accuracy: 54
#
#
# Model Training
#
# Epoch: 34
# Finished Training
# Training Loss: 420
#
#  Model Testing
#
# Epoch: 34
# Testing Accuracy: 54
#
#
# Model Training
#
# Epoch: 35
# Finished Training
# Training Loss: 419
#
#  Model Testing
#
# Epoch: 35
# Testing Accuracy: 54
#
#
# Model Training
#
# Epoch: 36
# Finished Training
# Training Loss: 417
#
#  Model Testing
#
# Epoch: 36
# Testing Accuracy: 54
#
#
# Model Training
#
# Epoch: 37
# Finished Training
# Training Loss: 414
#
#  Model Testing
#
# Epoch: 37
# Testing Accuracy: 55
#
#
# Model Training
#
# Epoch: 38
# Finished Training
# Training Loss: 412
#
#  Model Testing
#
# Epoch: 38
# Testing Accuracy: 55
#
#
# Model Training
#
# Epoch: 39
# Finished Training
# Training Loss: 409
#
#  Model Testing
#
# Epoch: 39
# Testing Accuracy: 55
#
#
# Model Training
#
# Epoch: 40
# Finished Training
# Training Loss: 408
#
#  Model Testing
#
# Epoch: 40
# Testing Accuracy: 54
#
#
# Model Training
#
# Epoch: 41
# Finished Training
# Training Loss: 407
#
#  Model Testing
#
# Epoch: 41
# Testing Accuracy: 54
#
#
# Model Training
#
# Epoch: 42
# Finished Training
# Training Loss: 407
#
#  Model Testing
#
# Epoch: 42
# Testing Accuracy: 56
#
#
# Model Training
#
# Epoch: 43
# Finished Training
# Training Loss: 403
#
#  Model Testing
#
# Epoch: 43
# Testing Accuracy: 56
#
#
# Model Training
#
# Epoch: 44
# Finished Training
# Training Loss: 400
#
#  Model Testing
#
# Epoch: 44
# Testing Accuracy: 56
#
#
# Model Training
#
# Epoch: 45
# Finished Training
# Training Loss: 400
#
#  Model Testing
#
# Epoch: 45
# Testing Accuracy: 56
#
#
# Model Training
#
# Epoch: 46
# Finished Training
# Training Loss: 401
#
#  Model Testing
#
# Epoch: 46
# Testing Accuracy: 56
#
#
# Model Training
#
# Epoch: 47
# Finished Training
# Training Loss: 398
#
#  Model Testing
#
# Epoch: 47
# Testing Accuracy: 56
#
#
# Model Training
#
# Epoch: 48
# Finished Training
# Training Loss: 399
#
#  Model Testing
#
# Epoch: 48
# Testing Accuracy: 56
#
#
# Model Training
#
# Epoch: 49
# Finished Training
# Training Loss: 397
#
#  Model Testing
#
# Epoch: 49
# Testing Accuracy: 56
#
#
# Model Training
#
# Epoch: 50
# Finished Training
# Training Loss: 393
#
#  Model Testing
#
# Epoch: 50
# Testing Accuracy: 57
#
#
# Model Training
#
# Epoch: 51
# Finished Training
# Training Loss: 391
#
#  Model Testing
#
# Epoch: 51
# Testing Accuracy: 57
#
#
# Model Training
#
# Epoch: 52
# Finished Training
# Training Loss: 393
#
#  Model Testing
#
# Epoch: 52
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 53
# Finished Training
# Training Loss: 390
#
#  Model Testing
#
# Epoch: 53
# Testing Accuracy: 57
#
#
# Model Training
#
# Epoch: 54
# Finished Training
# Training Loss: 388
#
#  Model Testing
#
# Epoch: 54
# Testing Accuracy: 57
#
#
# Model Training
#
# Epoch: 55
# Finished Training
# Training Loss: 389
#
#  Model Testing
#
# Epoch: 55
# Testing Accuracy: 57
#
#
# Model Training
#
# Epoch: 56
# Finished Training
# Training Loss: 387
#
#  Model Testing
#
# Epoch: 56
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 57
# Finished Training
# Training Loss: 385
#
#  Model Testing
#
# Epoch: 57
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 58
# Finished Training
# Training Loss: 385
#
#  Model Testing
#
# Epoch: 58
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 59
# Finished Training
# Training Loss: 384
#
#  Model Testing
#
# Epoch: 59
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 60
# Finished Training
# Training Loss: 384
#
#  Model Testing
#
# Epoch: 60
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 61
# Finished Training
# Training Loss: 382
#
#  Model Testing
#
# Epoch: 61
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 62
# Finished Training
# Training Loss: 382
#
#  Model Testing
#
# Epoch: 62
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 63
# Finished Training
# Training Loss: 380
#
#  Model Testing
#
# Epoch: 63
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 64
# Finished Training
# Training Loss: 380
#
#  Model Testing
#
# Epoch: 64
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 65
# Finished Training
# Training Loss: 378
#
#  Model Testing
#
# Epoch: 65
# Testing Accuracy: 58
#
#
# Model Training
#
# Epoch: 66
# Finished Training
# Training Loss: 378
#
#  Model Testing
#
# Epoch: 66
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 67
# Finished Training
# Training Loss: 375
#
#  Model Testing
#
# Epoch: 67
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 68
# Finished Training
# Training Loss: 376
#
#  Model Testing
#
# Epoch: 68
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 69
# Finished Training
# Training Loss: 377
#
#  Model Testing
#
# Epoch: 69
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 70
# Finished Training
# Training Loss: 375
#
#  Model Testing
#
# Epoch: 70
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 71
# Finished Training
# Training Loss: 373
#
#  Model Testing
#
# Epoch: 71
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 72
# Finished Training
# Training Loss: 373
#
#  Model Testing
#
# Epoch: 72
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 73
# Finished Training
# Training Loss: 373
#
#  Model Testing
#
# Epoch: 73
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 74
# Finished Training
# Training Loss: 371
#
#  Model Testing
#
# Epoch: 74
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 75
# Finished Training
# Training Loss: 370
#
#  Model Testing
#
# Epoch: 75
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 76
# Finished Training
# Training Loss: 371
#
#  Model Testing
#
# Epoch: 76
# Testing Accuracy: 59
#
#
# Model Training
#
# Epoch: 77
# Finished Training
# Training Loss: 367
#
#  Model Testing
#
# Epoch: 77
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 78
# Finished Training
# Training Loss: 368
#
#  Model Testing
#
# Epoch: 78
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 79
# Finished Training
# Training Loss: 365
#
#  Model Testing
#
# Epoch: 79
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 80
# Finished Training
# Training Loss: 368
#
#  Model Testing
#
# Epoch: 80
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 81
# Finished Training
# Training Loss: 367
#
#  Model Testing
#
# Epoch: 81
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 82
# Finished Training
# Training Loss: 365
#
#  Model Testing
#
# Epoch: 82
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 83
# Finished Training
# Training Loss: 364
#
#  Model Testing
#
# Epoch: 83
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 84
# Finished Training
# Training Loss: 365
#
#  Model Testing
#
# Epoch: 84
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 85
# Finished Training
# Training Loss: 363
#
#  Model Testing
#
# Epoch: 85
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 86
# Finished Training
# Training Loss: 363
#
#  Model Testing
#
# Epoch: 86
# Testing Accuracy: 60
#
#
# Model Training
#
# Epoch: 87
# Finished Training
# Training Loss: 364
#
#  Model Testing
#
# Epoch: 87
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 88
# Finished Training
# Training Loss: 361
#
#  Model Testing
#
# Epoch: 88
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 89
# Finished Training
# Training Loss: 360
#
#  Model Testing
#
# Epoch: 89
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 90
# Finished Training
# Training Loss: 362
#
#  Model Testing
#
# Epoch: 90
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 91
# Finished Training
# Training Loss: 361
#
#  Model Testing
#
# Epoch: 91
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 92
# Finished Training
# Training Loss: 359
#
#  Model Testing
#
# Epoch: 92
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 93
# Finished Training
# Training Loss: 358
#
#  Model Testing
#
# Epoch: 93
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 94
# Finished Training
# Training Loss: 359
#
#  Model Testing
#
# Epoch: 94
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 95
# Finished Training
# Training Loss: 358
#
#  Model Testing
#
# Epoch: 95
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 96
# Finished Training
# Training Loss: 355
#
#  Model Testing
#
# Epoch: 96
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 97
# Finished Training
# Training Loss: 357
#
#  Model Testing
#
# Epoch: 97
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 98
# Finished Training
# Training Loss: 356
#
#  Model Testing
#
# Epoch: 98
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 99
# Finished Training
# Training Loss: 352
#
#  Model Testing
#
# Epoch: 99
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 100
# Finished Training
# Training Loss: 357
#
#  Model Testing
#
# Epoch: 100
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 101
# Finished Training
# Training Loss: 354
#
#  Model Testing
#
# Epoch: 101
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 102
# Finished Training
# Training Loss: 353
#
#  Model Testing
#
# Epoch: 102
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 103
# Finished Training
# Training Loss: 353
#
#  Model Testing
#
# Epoch: 103
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 104
# Finished Training
# Training Loss: 354
#
#  Model Testing
#
# Epoch: 104
# Testing Accuracy: 61
#
#
# Model Training
#
# Epoch: 105
# Finished Training
# Training Loss: 351
#
#  Model Testing
#
# Epoch: 105
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 106
# Finished Training
# Training Loss: 351
#
#  Model Testing
#
# Epoch: 106
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 107
# Finished Training
# Training Loss: 351
#
#  Model Testing
#
# Epoch: 107
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 108
# Finished Training
# Training Loss: 354
#
#  Model Testing
#
# Epoch: 108
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 109
# Finished Training
# Training Loss: 352
#
#  Model Testing
#
# Epoch: 109
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 110
# Finished Training
# Training Loss: 350
#
#  Model Testing
#
# Epoch: 110
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 111
# Finished Training
# Training Loss: 351
#
#  Model Testing
#
# Epoch: 111
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 112
# Finished Training
# Training Loss: 349
#
#  Model Testing
#
# Epoch: 112
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 113
# Finished Training
# Training Loss: 352
#
#  Model Testing
#
# Epoch: 113
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 114
# Finished Training
# Training Loss: 349
#
#  Model Testing
#
# Epoch: 114
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 115
# Finished Training
# Training Loss: 347
#
#  Model Testing
#
# Epoch: 115
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 116
# Finished Training
# Training Loss: 349
#
#  Model Testing
#
# Epoch: 116
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 117
# Finished Training
# Training Loss: 347
#
#  Model Testing
#
# Epoch: 117
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 118
# Finished Training
# Training Loss: 347
#
#  Model Testing
#
# Epoch: 118
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 119
# Finished Training
# Training Loss: 347
#
#  Model Testing
#
# Epoch: 119
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 120
# Finished Training
# Training Loss: 347
#
#  Model Testing
#
# Epoch: 120
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 121
# Finished Training
# Training Loss: 345
#
#  Model Testing
#
# Epoch: 121
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 122
# Finished Training
# Training Loss: 346
#
#  Model Testing
#
# Epoch: 122
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 123
# Finished Training
# Training Loss: 347
#
#  Model Testing
#
# Epoch: 123
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 124
# Finished Training
# Training Loss: 344
#
#  Model Testing
#
# Epoch: 124
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 125
# Finished Training
# Training Loss: 344
#
#  Model Testing
#
# Epoch: 125
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 126
# Finished Training
# Training Loss: 344
#
#  Model Testing
#
# Epoch: 126
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 127
# Finished Training
# Training Loss: 344
#
#  Model Testing
#
# Epoch: 127
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 128
# Finished Training
# Training Loss: 343
#
#  Model Testing
#
# Epoch: 128
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 129
# Finished Training
# Training Loss: 344
#
#  Model Testing
#
# Epoch: 129
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 130
# Finished Training
# Training Loss: 344
#
#  Model Testing
#
# Epoch: 130
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 131
# Finished Training
# Training Loss: 343
#
#  Model Testing
#
# Epoch: 131
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 132
# Finished Training
# Training Loss: 342
#
#  Model Testing
#
# Epoch: 132
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 133
# Finished Training
# Training Loss: 343
#
#  Model Testing
#
# Epoch: 133
# Testing Accuracy: 62
#
#
# Model Training
#
# Epoch: 134
# Finished Training
# Training Loss: 339
#
#  Model Testing
#
# Epoch: 134
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 135
# Finished Training
# Training Loss: 342
#
#  Model Testing
#
# Epoch: 135
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 136
# Finished Training
# Training Loss: 339
#
#  Model Testing
#
# Epoch: 136
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 137
# Finished Training
# Training Loss: 340
#
#  Model Testing
#
# Epoch: 137
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 138
# Finished Training
# Training Loss: 340
#
#  Model Testing
#
# Epoch: 138
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 139
# Finished Training
# Training Loss: 340
#
#  Model Testing
#
# Epoch: 139
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 140
# Finished Training
# Training Loss: 338
#
#  Model Testing
#
# Epoch: 140
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 141
# Finished Training
# Training Loss: 339
#
#  Model Testing
#
# Epoch: 141
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 142
# Finished Training
# Training Loss: 341
#
#  Model Testing
#
# Epoch: 142
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 143
# Finished Training
# Training Loss: 338
#
#  Model Testing
#
# Epoch: 143
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 144
# Finished Training
# Training Loss: 338
#
#  Model Testing
#
# Epoch: 144
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 145
# Finished Training
# Training Loss: 337
#
#  Model Testing
#
# Epoch: 145
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 146
# Finished Training
# Training Loss: 338
#
#  Model Testing
#
# Epoch: 146
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 147
# Finished Training
# Training Loss: 336
#
#  Model Testing
#
# Epoch: 147
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 148
# Finished Training
# Training Loss: 337
#
#  Model Testing
#
# Epoch: 148
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 149
# Finished Training
# Training Loss: 336
#
#  Model Testing
#
# Epoch: 149
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 150
# Finished Training
# Training Loss: 336
#
#  Model Testing
#
# Epoch: 150
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 151
# Finished Training
# Training Loss: 334
#
#  Model Testing
#
# Epoch: 151
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 152
# Finished Training
# Training Loss: 334
#
#  Model Testing
#
# Epoch: 152
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 153
# Finished Training
# Training Loss: 336
#
#  Model Testing
#
# Epoch: 153
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 154
# Finished Training
# Training Loss: 334
#
#  Model Testing
#
# Epoch: 154
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 155
# Finished Training
# Training Loss: 336
#
#  Model Testing
#
# Epoch: 155
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 156
# Finished Training
# Training Loss: 334
#
#  Model Testing
#
# Epoch: 156
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 157
# Finished Training
# Training Loss: 333
#
#  Model Testing
#
# Epoch: 157
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 158
# Finished Training
# Training Loss: 333
#
#  Model Testing
#
# Epoch: 158
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 159
# Finished Training
# Training Loss: 333
#
#  Model Testing
#
# Epoch: 159
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 160
# Finished Training
# Training Loss: 333
#
#  Model Testing
#
# Epoch: 160
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 161
# Finished Training
# Training Loss: 332
#
#  Model Testing
#
# Epoch: 161
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 162
# Finished Training
# Training Loss: 332
#
#  Model Testing
#
# Epoch: 162
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 163
# Finished Training
# Training Loss: 332
#
#  Model Testing
#
# Epoch: 163
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 164
# Finished Training
# Training Loss: 333
#
#  Model Testing
#
# Epoch: 164
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 165
# Finished Training
# Training Loss: 332
#
#  Model Testing
#
# Epoch: 165
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 166
# Finished Training
# Training Loss: 330
#
#  Model Testing
#
# Epoch: 166
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 167
# Finished Training
# Training Loss: 331
#
#  Model Testing
#
# Epoch: 167
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 168
# Finished Training
# Training Loss: 330
#
#  Model Testing
#
# Epoch: 168
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 169
# Finished Training
# Training Loss: 330
#
#  Model Testing
#
# Epoch: 169
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 170
# Finished Training
# Training Loss: 330
#
#  Model Testing
#
# Epoch: 170
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 171
# Finished Training
# Training Loss: 329
#
#  Model Testing
#
# Epoch: 171
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 172
# Finished Training
# Training Loss: 328
#
#  Model Testing
#
# Epoch: 172
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 173
# Finished Training
# Training Loss: 328
#
#  Model Testing
#
# Epoch: 173
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 174
# Finished Training
# Training Loss: 329
#
#  Model Testing
#
# Epoch: 174
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 175
# Finished Training
# Training Loss: 328
#
#  Model Testing
#
# Epoch: 175
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 176
# Finished Training
# Training Loss: 329
#
#  Model Testing
#
# Epoch: 176
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 177
# Finished Training
# Training Loss: 328
#
#  Model Testing
#
# Epoch: 177
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 178
# Finished Training
# Training Loss: 328
#
#  Model Testing
#
# Epoch: 178
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 179
# Finished Training
# Training Loss: 329
#
#  Model Testing
#
# Epoch: 179
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 180
# Finished Training
# Training Loss: 326
#
#  Model Testing
#
# Epoch: 180
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 181
# Finished Training
# Training Loss: 326
#
#  Model Testing
#
# Epoch: 181
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 182
# Finished Training
# Training Loss: 326
#
#  Model Testing
#
# Epoch: 182
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 183
# Finished Training
# Training Loss: 326
#
#  Model Testing
#
# Epoch: 183
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 184
# Finished Training
# Training Loss: 325
#
#  Model Testing
#
# Epoch: 184
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 185
# Finished Training
# Training Loss: 325
#
#  Model Testing
#
# Epoch: 185
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 186
# Finished Training
# Training Loss: 326
#
#  Model Testing
#
# Epoch: 186
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 187
# Finished Training
# Training Loss: 325
#
#  Model Testing
#
# Epoch: 187
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 188
# Finished Training
# Training Loss: 323
#
#  Model Testing
#
# Epoch: 188
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 189
# Finished Training
# Training Loss: 326
#
#  Model Testing
#
# Epoch: 189
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 190
# Finished Training
# Training Loss: 323
#
#  Model Testing
#
# Epoch: 190
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 191
# Finished Training
# Training Loss: 326
#
#  Model Testing
#
# Epoch: 191
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 192
# Finished Training
# Training Loss: 324
#
#  Model Testing
#
# Epoch: 192
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 193
# Finished Training
# Training Loss: 324
#
#  Model Testing
#
# Epoch: 193
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 194
# Finished Training
# Training Loss: 327
#
#  Model Testing
#
# Epoch: 194
# Testing Accuracy: 63
#
#
# Model Training
#
# Epoch: 195
# Finished Training
# Training Loss: 324
#
#  Model Testing
#
# Epoch: 195
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 196
# Finished Training
# Training Loss: 324
#
#  Model Testing
#
# Epoch: 196
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 197
# Finished Training
# Training Loss: 321
#
#  Model Testing
#
# Epoch: 197
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 198
# Finished Training
# Training Loss: 325
#
#  Model Testing
#
# Epoch: 198
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 199
# Finished Training
# Training Loss: 324
#
#  Model Testing
#
# Epoch: 199
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 200
# Finished Training
# Training Loss: 325
#
#  Model Testing
#
# Epoch: 200
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 201
# Finished Training
# Training Loss: 322
#
#  Model Testing
#
# Epoch: 201
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 202
# Finished Training
# Training Loss: 323
#
#  Model Testing
#
# Epoch: 202
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 203
# Finished Training
# Training Loss: 321
#
#  Model Testing
#
# Epoch: 203
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 204
# Finished Training
# Training Loss: 322
#
#  Model Testing
#
# Epoch: 204
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 205
# Finished Training
# Training Loss: 320
#
#  Model Testing
#
# Epoch: 205
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 206
# Finished Training
# Training Loss: 322
#
#  Model Testing
#
# Epoch: 206
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 207
# Finished Training
# Training Loss: 320
#
#  Model Testing
#
# Epoch: 207
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 208
# Finished Training
# Training Loss: 320
#
#  Model Testing
#
# Epoch: 208
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 209
# Finished Training
# Training Loss: 320
#
#  Model Testing
#
# Epoch: 209
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 210
# Finished Training
# Training Loss: 321
#
#  Model Testing
#
# Epoch: 210
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 211
# Finished Training
# Training Loss: 321
#
#  Model Testing
#
# Epoch: 211
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 212
# Finished Training
# Training Loss: 321
#
#  Model Testing
#
# Epoch: 212
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 213
# Finished Training
# Training Loss: 319
#
#  Model Testing
#
# Epoch: 213
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 214
# Finished Training
# Training Loss: 318
#
#  Model Testing
#
# Epoch: 214
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 215
# Finished Training
# Training Loss: 318
#
#  Model Testing
#
# Epoch: 215
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 216
# Finished Training
# Training Loss: 318
#
#  Model Testing
#
# Epoch: 216
# Testing Accuracy: 64
#
#
# Model Training
#
# Epoch: 217
# Finished Training
# Training Loss: 320
#
#  Model Testing
#
# Epoch: 217
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 218
# Finished Training
# Training Loss: 318
#
#  Model Testing
#
# Epoch: 218
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 219
# Finished Training
# Training Loss: 319
#
#  Model Testing
#
# Epoch: 219
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 220
# Finished Training
# Training Loss: 318
#
#  Model Testing
#
# Epoch: 220
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 221
# Finished Training
# Training Loss: 317
#
#  Model Testing
#
# Epoch: 221
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 222
# Finished Training
# Training Loss: 319
#
#  Model Testing
#
# Epoch: 222
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 223
# Finished Training
# Training Loss: 318
#
#  Model Testing
#
# Epoch: 223
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 224
# Finished Training
# Training Loss: 317
#
#  Model Testing
#
# Epoch: 224
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 225
# Finished Training
# Training Loss: 318
#
#  Model Testing
#
# Epoch: 225
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 226
# Finished Training
# Training Loss: 317
#
#  Model Testing
#
# Epoch: 226
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 227
# Finished Training
# Training Loss: 318
#
#  Model Testing
#
# Epoch: 227
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 228
# Finished Training
# Training Loss: 316
#
#  Model Testing
#
# Epoch: 228
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 229
# Finished Training
# Training Loss: 316
#
#  Model Testing
#
# Epoch: 229
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 230
# Finished Training
# Training Loss: 317
#
#  Model Testing
#
# Epoch: 230
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 231
# Finished Training
# Training Loss: 316
#
#  Model Testing
#
# Epoch: 231
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 232
# Finished Training
# Training Loss: 316
#
#  Model Testing
#
# Epoch: 232
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 233
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 233
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 234
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 234
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 235
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 235
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 236
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 236
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 237
# Finished Training
# Training Loss: 314
#
#  Model Testing
#
# Epoch: 237
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 238
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 238
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 239
# Finished Training
# Training Loss: 313
#
#  Model Testing
#
# Epoch: 239
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 240
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 240
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 241
# Finished Training
# Training Loss: 314
#
#  Model Testing
#
# Epoch: 241
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 242
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 242
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 243
# Finished Training
# Training Loss: 313
#
#  Model Testing
#
# Epoch: 243
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 244
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 244
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 245
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 245
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 246
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 246
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 247
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 247
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 248
# Finished Training
# Training Loss: 315
#
#  Model Testing
#
# Epoch: 248
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 249
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 249
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 250
# Finished Training
# Training Loss: 314
#
#  Model Testing
#
# Epoch: 250
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 251
# Finished Training
# Training Loss: 313
#
#  Model Testing
#
# Epoch: 251
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 252
# Finished Training
# Training Loss: 313
#
#  Model Testing
#
# Epoch: 252
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 253
# Finished Training
# Training Loss: 312
#
#  Model Testing
#
# Epoch: 253
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 254
# Finished Training
# Training Loss: 314
#
#  Model Testing
#
# Epoch: 254
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 255
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 255
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 256
# Finished Training
# Training Loss: 312
#
#  Model Testing
#
# Epoch: 256
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 257
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 257
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 258
# Finished Training
# Training Loss: 313
#
#  Model Testing
#
# Epoch: 258
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 259
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 259
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 260
# Finished Training
# Training Loss: 310
#
#  Model Testing
#
# Epoch: 260
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 261
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 261
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 262
# Finished Training
# Training Loss: 310
#
#  Model Testing
#
# Epoch: 262
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 263
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 263
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 264
# Finished Training
# Training Loss: 312
#
#  Model Testing
#
# Epoch: 264
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 265
# Finished Training
# Training Loss: 312
#
#  Model Testing
#
# Epoch: 265
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 266
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 266
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 267
# Finished Training
# Training Loss: 310
#
#  Model Testing
#
# Epoch: 267
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 268
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 268
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 269
# Finished Training
# Training Loss: 311
#
#  Model Testing
#
# Epoch: 269
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 270
# Finished Training
# Training Loss: 309
#
#  Model Testing
#
# Epoch: 270
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 271
# Finished Training
# Training Loss: 308
#
#  Model Testing
#
# Epoch: 271
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 272
# Finished Training
# Training Loss: 310
#
#  Model Testing
#
# Epoch: 272
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 273
# Finished Training
# Training Loss: 309
#
#  Model Testing
#
# Epoch: 273
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 274
# Finished Training
# Training Loss: 309
#
#  Model Testing
#
# Epoch: 274
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 275
# Finished Training
# Training Loss: 309
#
#  Model Testing
#
# Epoch: 275
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 276
# Finished Training
# Training Loss: 310
#
#  Model Testing
#
# Epoch: 276
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 277
# Finished Training
# Training Loss: 309
#
#  Model Testing
#
# Epoch: 277
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 278
# Finished Training
# Training Loss: 310
#
#  Model Testing
#
# Epoch: 278
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 279
# Finished Training
# Training Loss: 309
#
#  Model Testing
#
# Epoch: 279
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 280
# Finished Training
# Training Loss: 308
#
#  Model Testing
#
# Epoch: 280
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 281
# Finished Training
# Training Loss: 309
#
#  Model Testing
#
# Epoch: 281
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 282
# Finished Training
# Training Loss: 308
#
#  Model Testing
#
# Epoch: 282
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 283
# Finished Training
# Training Loss: 307
#
#  Model Testing
#
# Epoch: 283
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 284
# Finished Training
# Training Loss: 308
#
#  Model Testing
#
# Epoch: 284
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 285
# Finished Training
# Training Loss: 309
#
#  Model Testing
#
# Epoch: 285
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 286
# Finished Training
# Training Loss: 307
#
#  Model Testing
#
# Epoch: 286
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 287
# Finished Training
# Training Loss: 308
#
#  Model Testing
#
# Epoch: 287
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 288
# Finished Training
# Training Loss: 307
#
#  Model Testing
#
# Epoch: 288
# Testing Accuracy: 65
#
#
# Model Training
#
# Epoch: 289
# Finished Training
# Training Loss: 306
#
#  Model Testing
#
# Epoch: 289
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 290
# Finished Training
# Training Loss: 306
#
#  Model Testing
#
# Epoch: 290
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 291
# Finished Training
# Training Loss: 308
#
#  Model Testing
#
# Epoch: 291
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 292
# Finished Training
# Training Loss: 308
#
#  Model Testing
#
# Epoch: 292
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 293
# Finished Training
# Training Loss: 308
#
#  Model Testing
#
# Epoch: 293
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 294
# Finished Training
# Training Loss: 307
#
#  Model Testing
#
# Epoch: 294
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 295
# Finished Training
# Training Loss: 306
#
#  Model Testing
#
# Epoch: 295
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 296
# Finished Training
# Training Loss: 307
#
#  Model Testing
#
# Epoch: 296
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 297
# Finished Training
# Training Loss: 307
#
#  Model Testing
#
# Epoch: 297
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 298
# Finished Training
# Training Loss: 305
#
#  Model Testing
#
# Epoch: 298
# Testing Accuracy: 66
#
#
# Model Training
#
# Epoch: 299
# Finished Training
# Training Loss: 306

# %%
def predict_with_best_param(net):
  ## Loading the best model parameters 
  PATH ='./cifar_net.pth'
  net.load_state_dict(torch.load(PATH))
  # prepare to count predictions for each class
  correct_pred = {classname: 0 for classname in classes}
  total_pred = {classname: 0 for classname in classes}

  # again no gradients needed
  with torch.no_grad():
      for batch_id, (images, labels) in enumerate(testloader):
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          _, predictions = torch.max(outputs, 1)
          # collect the correct predictions for each class
          for label, prediction in zip(labels, predictions):
              if label == prediction:   
                  correct_pred[classes[label]] += 1
              total_pred[classes[label]] += 1


  # print accuracy for each class
  for classname, correct_count in correct_pred.items():
      accuracy = 100 * float(correct_count) / total_pred[classname]
      print("Accuracy for class {:5s} is: {:.1f} %".format(classname,
                                                    accuracy))

# %%
def confusion_matrix_plot(net):
  total_correct = 0
  total_images = 0
  confusion_matrix = np.zeros([10,10], int)
  with torch.no_grad():
      for batch_id, (images, labels) in enumerate(testloader):
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          _, predicted = torch.max(outputs.data, 1)
          total_images += labels.size(0)
          total_correct += (predicted == labels).sum().item()
          for i, l in enumerate(labels):
              confusion_matrix[l.item(), predicted[i].item()] += 1 

  model_accuracy = total_correct / total_images * 100
  print('Model accuracy on {0} test images: {1:.2f}%'.format(total_images, model_accuracy))
  fig, ax = plt.subplots(1,1,figsize=(8,6))
  sns.heatmap(confusion_matrix,annot = True,fmt='d')
  plt.ylabel('Actual Category')
  plt.yticks(range(10), classes)
  plt.xlabel('Predicted Category')
  plt.xticks(range(10), classes)
  plt.show()

# %%
running_loss_history
# Out:
# [484.3179432153702,
#  479.0436877012253,
#  476.9014000892639,
#  473.05411863327026,
#  468.1339191198349]

# %%
val_running_loss_history
# Out:
# [120.29618537425995,
#  120.35218560695648,
#  119.53222262859344,
#  117.76254731416702,
#  118.70366036891937]

# %%
### Defining a Loss function and optimizer for configuration 2
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
training_testing()
# Out:
# Training
#
# Epoch: 0
# Finished Training
# 684.7015385627747
# Testing
#
# 39.88
# Training
#
# Epoch: 1
# Finished Training
# 670.8203579187393
# Testing
#
# 40.78
# Training
#
# Epoch: 2
# Finished Training
# 659.5142143964767
# Testing
#
# 41.88
# Training
#
# Epoch: 3
# Finished Training
# 648.096148610115
# Testing
#
# 43.13
# Training
#
# Epoch: 4
# Finished Training
# 637.0372648239136
# Testing
#
# 44.2

# %%
line_eng = open('/content/train_loss.txt',encoding='utf-8').read().strip().split('\n')

# %%
line_eng
# Out:
# ['0 626.3478435277939',
#  '1 617.1287066936493',
#  '2 608.6173219680786',
#  '3 599.8985217809677',
#  '4 591.4995070695877']

# %%
## Loading the best model parameters 
PATH ='./cifar_net.pth'
net.load_state_dict(torch.load(PATH))
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for batch_id, (images, labels) in enumerate(testloader):
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:   
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print("Accuracy for class {:5s} is: {:.1f} %".format(classname,
                                                   accuracy))
# Out:
# Accuracy for class plane is: 50.7 %
# Accuracy for class car   is: 75.1 %
# Accuracy for class bird  is: 24.8 %
# Accuracy for class cat   is: 25.2 %
# Accuracy for class deer  is: 36.6 %
# Accuracy for class dog   is: 46.6 %
# Accuracy for class frog  is: 64.0 %
# Accuracy for class horse is: 53.9 %
# Accuracy for class ship  is: 69.2 %
# Accuracy for class truck is: 51.9 %

# %%
total_correct = 0
total_images = 0
confusion_matrix = np.zeros([10,10], int)
with torch.no_grad():
    for batch_id, (images, labels) in enumerate(testloader):
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total_images += labels.size(0)
        total_correct += (predicted == labels).sum().item()
        for i, l in enumerate(labels):
            confusion_matrix[l.item(), predicted[i].item()] += 1 

model_accuracy = total_correct / total_images * 100
print('Model accuracy on {0} test images: {1:.2f}%'.format(total_images, model_accuracy))
# Out:
# Model accuracy on 10000 test images: 49.80%

# %%
fig, ax = plt.subplots(1,1,figsize=(8,6))
sns.heatmap(confusion_matrix,annot = True,fmt='d')
plt.ylabel('Actual Category')
plt.yticks(range(10), classes)
plt.xlabel('Predicted Category')
plt.xticks(range(10), classes)
plt.show()

# %%
correct_pred
# Out:
# {'bird': 0,
#  'car': 0,
#  'cat': 0,
#  'deer': 0,
#  'dog': 0,
#  'frog': 0,
#  'horse': 0,
#  'plane': 0,
#  'ship': 0,
#  'truck': 0}

# %%
## Defining a resnet model
rn18 = models.resnet18(pretrained=True)
rn18
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
## Getting the penultimate layer output so that we can define our own fc from there
input_to_fc=rn18.fc.in_features
rn18.fc = nn.Linear(input_to_fc, 256)
rn18.fc1 = nn.Linear(256,128)
rn18.fc2 = nn.Linear(128,10)

# %%
rn18.modules
# Out:
# <bound method Module.modules of ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=256, bias=True)
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )>

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(rn18.parameters(), lr=0.01, momentum=0.9)

# %%
rn18 = rn18.to(device)
running_loss_history = []
val_running_loss_history = []
training_testing(rn18,criterion, optimizer)
# Out:
# Model Training
#
# Epoch: 0
# Finished Training
# Training Loss: 359
#
#  Model Testing
#
# Epoch: 0
# Testing Accuracy: 74
#
#
# Model Training
#
# Epoch: 1
# Finished Training
# Training Loss: 238
#
#  Model Testing
#
# Epoch: 1
# Testing Accuracy: 77
#
#
# Model Training
#
# Epoch: 2
# Finished Training
# Training Loss: 202
#
#  Model Testing
#
# Epoch: 2
# Testing Accuracy: 79
#
#
# Model Training
#
# Epoch: 3
# Finished Training
# Training Loss: 183
#
#  Model Testing
#
# Epoch: 3
# Testing Accuracy: 79
#
#
# Model Training
#
# Epoch: 4
# Finished Training
# Training Loss: 169
#
#  Model Testing
#
# Epoch: 4
# Testing Accuracy: 81
#
#
# Model Training
#
# Epoch: 5
# Finished Training
# Training Loss: 157
#
#  Model Testing
#
# Epoch: 5
# Testing Accuracy: 81
#
#
# Model Training
#
# Epoch: 6
# Finished Training
# Training Loss: 148
#
#  Model Testing
#
# Epoch: 6
# Testing Accuracy: 80
#
#
# Model Training
#
# Epoch: 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-c6b86037832a> in <module>()
#       2 running_loss_history = []
#       3 val_running_loss_history = []
# ----> 4 training_testing(rn18,criterion, optimizer)
#
# <ipython-input-63-ca218d06dd51> in training_testing(net, criterion, optimizer)
#       4   for epoch in range(0,20):
#       5     print("Model Training")
# ----> 6     train(epoch,net,criterion,optimizer)
#       7     if val_running_loss_history[epoch]>val_running_loss_history[epoch-1]:
#       8       if(epochs_no_improve<n_epochs_stop):
#
# <ipython-input-61-d9a49538ecb3> in train(epoch, net, criterion, optimizer)
#      19
#      20         # print statistics
# ---> 21         running_loss += loss.item()
#      22     running_loss_history.append(running_loss)
#      23     #Write training losses to losstrain.txt for each epoch
#
# KeyboardInterrupt:
